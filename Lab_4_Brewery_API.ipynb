# %% [markdown]
# # Lab 4: Working with JSON Data from the Open Brewery DB API
#
# **Create a copy of this notebook and follow the steps below**
#
# This notebook gives you starter code to use the **Open Brewery DB API** to extract data about breweries across the United States. This is a public API that does not require authentication, making it perfect for learning about APIs and JSON data.
#
# You should review the DataCamp chapter **"Importing JSON Data and Working with APIs"** (Part of Course: Streamlined Data Ingestion with Pandas) before starting this exercise. This counts for class participation credit.
#
# ## Learning Objectives
# - Understand how to work with RESTful APIs
# - Parse JSON responses into Python dictionaries
# - Convert JSON data to pandas DataFrames
# - Use API query parameters to filter data
# - Combine data from multiple API calls
#
# ## Resources
# - **API Documentation:** http://178.156.206.171:8000/docs
# - **What is an API?** https://www.mulesoft.com/resources/api/what-is-an-api
# - **JSON and APIs with Python:** https://towardsdatascience.com/json-and-apis-with-python-fba329ef6ef0

# %% [markdown]
# ## Let's start with importing libraries to extract data from the Brewery API

# %%
# Standard Python library for handling HTTP requests
import requests

# Import pandas for data manipulation
import pandas as pd

# Import json for pretty printing JSON data
import json

# %% [markdown]
# ## Understanding API Calls
#
# The Open Brewery DB API is completely **open and requires no authentication**. This means:
# - ✅ No API key needed
# - ✅ No registration required
# - ✅ No rate limits for reasonable use
#
# To GET data from the API, we need:
# 1. **A URL** - The base API endpoint
# 2. **Parameters** - Query parameters to filter/search data
# 3. **HTTP GET request** - Using the `requests` library
#
# ### Available Endpoints
# Our brewery API has several endpoints:
# - `/breweries` - List breweries with filters
# - `/breweries/search` - Full-text search
# - `/breweries/random` - Get random brewery(ies)
# - `/breweries/autocomplete` - Name autocomplete
# - `/breweries/{id}` - Get specific brewery by ID
# - `/breweries/meta` - Get brewery count metadata
#
# You can view interactive documentation at: http://178.156.206.171:8000/docs

# %% [markdown]
# ## Example Query: Search for Breweries
#
# Let's search for breweries with the term "dog" in their name. This will demonstrate the basic pattern for making API calls.

# %%
# The base API URL
base_url = 'http://178.156.206.171:8000'

# The search endpoint
search_url = f'{base_url}/breweries/search'

# Query parameters - search for breweries with 'dog' in the name
params = {
    'query': 'dog',
    'per_page': 10  # Limit to 10 results
}

print(f"Making request to: {search_url}")
print(f"With parameters: {params}")
# Out:
# Making request to: http://178.156.206.171:8000/breweries/search
# With parameters: {'query': 'dog', 'per_page': 10}

# %%
# Make the GET request
# We set timeout=5 to stop waiting after 5 seconds
response = requests.get(search_url, params=params, timeout=5)

# Check if the request was successful
print(f"Status Code: {response.status_code}")
print(f"Response URL: {response.url}")

# Extract JSON data from the response
data = response.json()

# Print the JSON data (nicely formatted)
print("\nJSON Response:")
print(json.dumps(data[:2], indent=2))  # Show first 2 results only for readability
# Out:
# Status Code: 200
# Response URL: http://178.156.206.171:8000/breweries/search?query=dog&per_page=10
#
# JSON Response:
# [
#   {
#     "id": "8436b02b-9a06-474c-b5eb-8ff9aedf1f99",
#     "name": "2 Dogz and A Guy Brewing",
#     "brewery_type": "micro",
#     "address_1": "228 Church St",
#     "address_2": null,
#     "address_3": null,
#     "city": "Montrose",
#     "state_province": "Pennsylvania",
#     "postal_code": "18801-1271",
#     "country": "United States",
#     "phone": "5704320069",
#     "website_url": "http://2dogzandaguybrewing.com",
#     "longitude": -75.8800318,
#     "latitude": 41.8336364
#   },
#   {
#     "id": "9d64f11c-4f42-41c6-8ba7-768f7bf9ec13",
#     "name": "Alpine Dog Brewing Co",
#     "brewery_type": "micro",
#     "address_1": "1505 N Ogden St",
#     "address_2": null,
#     "address_3": null,
#     "city": "Denver",
#     "state_province": "Colorado",
#     "postal_code": "80218-1405",
#     "country": "United States",
#     "phone": "3038321245",
#     "website_url": "http://www.alpinedogbrewery.com",
#     "longitude": null,
#     "latitude": null
#   }
# ]

# %%
# Convert JSON data to pandas DataFrame
# The API returns a list of brewery dictionaries directly
df = pd.DataFrame(data)

# Display the top 5 rows
print(f"Found {len(df)} breweries")
df.head()
# Out:
# Found 10 breweries
#                                      id                      name  \
# 0  8436b02b-9a06-474c-b5eb-8ff9aedf1f99  2 Dogz and A Guy Brewing
# 1  9d64f11c-4f42-41c6-8ba7-768f7bf9ec13     Alpine Dog Brewing Co
# 2  d493c084-8f5c-4e04-994b-ddc55fcd3959      Bad Bulldogs Brewery
# 3  2907b143-57b4-49ec-aa41-07df64d1e14b        Barrel Dog Brewing
# 4  2c048f27-d9fc-4117-ae9a-c3c79ea2470e      Big Dog's Brewing Co
#
#   brewery_type               address_1 address_2 address_3       city  \
# 0        micro           228 Church St      None      None   Montrose
# 1        micro         1505 N Ogden St      None      None     Denver
# 2       closed        941 N Callow Ave      None      None  Bremerton
# 3        micro                    None      None      None  Evergreen
# 4      brewpub  4547 N Rancho Dr Ste A      None      None  Las Vegas
#
#   state_province postal_code        country       phone  \
# 0   Pennsylvania  18801-1271  United States  5704320069
# 1       Colorado  80218-1405  United States  3038321245
# 2     Washington       98312  United States  3606278079
# 3       Colorado       80439  United States  5599176846
# 4         Nevada  89130-3432  United States  7023683715
#
#                        website_url   longitude   latitude
# 0   http://2dogzandaguybrewing.com  -75.880032  41.833636
# 1  http://www.alpinedogbrewery.com         NaN        NaN
# 2                             None -122.653374  47.569639
# 3                             None -105.321458  39.636164
# 4      http://www.bigdogsbrews.com         NaN        NaN

# %% [markdown]
# ## Exploring the Data Structure
#
# Let's examine what data is available for each brewery.

# %%
# View all available columns
print("Available columns:")
print(df.columns.tolist())

# View data types
print("\nData types:")
print(df.dtypes)

# View basic statistics
print("\nDataset shape:")
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
# Out:
# Available columns:
# ['id', 'name', 'brewery_type', 'address_1', 'address_2', 'address_3', 'city', 'state_province', 'postal_code', 'country', 'phone', 'website_url', 'longitude', 'latitude']
#
# Data types:
# id                 object
# name               object
# brewery_type       object
# address_1          object
# address_2          object
# address_3          object
# city               object
# state_province     object
# postal_code        object
# country            object
# phone              object
# website_url        object
# longitude         float64
# latitude          float64
# dtype: object
#
# Dataset shape:
# Rows: 10, Columns: 14

# %% [markdown]
# ---
#
# # Lab Assignment
#
# Complete the following tasks for class participation credit:
#
# ## Task 1: Search Endpoint Queries (3 queries)
#
# Use the `/breweries/search` endpoint with **three different search terms**. For each query:
# - Create separate params (params1, params2, params3)
# - Store responses in different variables (response1, response2, response3)
# - Create separate DataFrames (df1, df2, df3)
# - Display the top 5 rows of each DataFrame
#
# **Example search terms:**
# - "brewing"
# - "mountain"
# - "craft"
# - "beer"
# - Any term of your choice!
#
# ### Query 1
# Write your code below:

# %%
# Your code for Query 1 here
params1 = {
    'query': 'YOUR_SEARCH_TERM',
    'per_page': 10
}
url = "https://api.openbrewerydb.org/v1/breweries/search"
response1 = requests.get(url, params=params1)
df1 = pd.DataFrame(response1.json())
df1.head()
# Out:
#                                      id                          name  \
# 0  1ca6480d-7d22-43b5-af4e-3be6939ccb65         Your Mates Brewing Co
# 1  f087a1a9-5d5b-471f-926e-d37a68d2983d            Your Mates Brewery
# 2  59dee189-7a16-4a13-a913-620994d7b548  Elevate Your Passion Brewing
#
#   brewery_type             address_1 address_2 address_3    city  \
# 0        micro   41 Technology Drive      None      None  Warana
# 1        micro   41 Technology Drive      None      None  Warana
# 2        micro  2209 W 1st St # A107      None      None   Tempe
#
#   state_province postal_code        country   longitude   latitude  \
# 0            QLD        4575      Australia  153.123229 -26.726955
# 1            QLD        4575      Australia  153.123229 -26.726955
# 2        Arizona  85281-7245  United States         NaN        NaN
#
#              phone                        website_url    state  \
# 0  +61 7 5329 4733       http://yourmatesbrewing.com/      QLD
# 1  +61 7 5329 4733       http://yourmatesbrewing.com/      QLD
# 2       8883972337  http://www.elevateyourpassion.com  Arizona
#
#                  street
# 0   41 Technology Drive
# 1   41 Technology Drive
# 2  2209 W 1st St # A107

# %% [markdown]
# ### Query 2
# Write your code below:

# %%
# Your code for Query 2 here
params2 = {
    'query': 'mountain',   # 🔹 change search term for Query 2
    'per_page': 10
}

url = "https://api.openbrewerydb.org/v1/breweries/search"
response2 = requests.get(url, params=params2)
df2 = pd.DataFrame(response2.json())
df2.head()
# Out:
#                                      id  \
# 0  251596fe-58b7-4690-a823-f8c65be73228
# 1  2ad0448b-96e8-4537-b990-9cbf5e4702db
# 2  335bffa7-c0f1-4593-929c-1f80ed7ab7c6
# 3  378d7eee-7a3b-41ea-a4b1-c27c35c28b07
# 4  568ece36-a3d7-40ad-9364-592642a1cdd3
#
#                                           name brewery_type  \
# 0                        Mountain View Brewing        micro
# 1                      Mountain Valley Brewing        micro
# 2  Mountain Town Station Restaurant & Brew Pub      brewpub
# 3                        Mountain Base Brewery        micro
# 4                         Palo Alto Brewing Co     contract
#
#                    address_1 address_2 address_3           city  \
# 0  6670 Trout Creek Ridge Rd      None      None        Mt Hood
# 1    4220 Mountain Valley Rd      None      None          Axton
# 2          506 W Broadway St      None      None    Mt Pleasant
# 3           553 Mast Rd #111      None      None      Goffstown
# 4        1080B La Avenida St      None      None  Mountain View
#
#   state_province postal_code        country   longitude   latitude  \
# 0         Oregon       97041  United States -121.622974  45.537074
# 1       Virginia  24054-2985  United States  -79.707210  36.715687
# 2       Michigan  48858-2441  United States  -84.782220  43.604568
# 3  New Hampshire       03045  United States  -71.515320  43.001280
# 4     California  94043-1422  United States -122.071766  37.413268
#
#         phone                           website_url          state  \
# 0  5414410314        https://www.mtviewbrewing.com/         Oregon
# 1  2768332171                                  None       Virginia
# 2  9894004666       http://www.mountaintownbrew.com       Michigan
# 3  6039357132  https://www.mountainbasebrewery.com/  New Hampshire
# 4        None        http://www.paloaltobrewing.com     California
#
#                       street
# 0  6670 Trout Creek Ridge Rd
# 1    4220 Mountain Valley Rd
# 2          506 W Broadway St
# 3           553 Mast Rd #111
# 4        1080B La Avenida St

# %% [markdown]
# ### Query 3
# Write your code below:

# %%
# Your code for Query 3 here
params3 = {
    'query': 'craft',   # 🔹 new search term for Query 3
    'per_page': 10
}
url = "https://api.openbrewerydb.org/v1/breweries/search"
response3 = requests.get(url, params=params3)
df3 = pd.DataFrame(response3.json())
df3.head()
# Out:
#                                      id                         name  \
# 0  312232fc-cbec-44aa-bc5b-85cac76e3c43        Craft Brewing Company
# 1  4a093277-4333-401e-b484-b231145a0d26    Craft Kitchen and Brewery
# 2  52048a4e-8f81-4515-bc5e-9289da7fcead           Craft Life Brewing
# 3  728019cb-061f-45e9-b3af-6b8ea811258d                     CRAFT 64
# 4  74716bad-707a-449f-b278-c48148587be2  CRAFT BEER BASE MOTHER TREE
#
#   brewery_type                 address_1 address_2 address_3           city  \
# 0        micro              530 Crane St      None      None  Lake Elsinore
# 1      brewpub  62988 Layton Ave Ste 103      None      None           Bend
# 2        micro    2624 Land O Lakes Blvd      None      None   Land O Lakes
# 3     contract            6922 E Main St      None      None     Scottsdale
# 4      brewpub         1-13-13 Oyodonaka      None      None          Osaka
#
#   state_province postal_code        country   longitude   latitude  \
# 0     California  92530-2779  United States -117.340249  33.686738
# 1         Oregon  97701-6692  United States -121.290365  44.087193
# 2        Florida  34639-4910  United States  -82.464779  28.196146
# 3        Arizona  85251-4312  United States -111.931927  33.493153
# 4          Osaka    531-0076          Japan  135.488708  34.705129
#
#          phone                                 website_url       state  \
# 0   9516742562          http://www.craftbrewibgcompany.com  California
# 1   5416681766       http://www.craftkitchenandbrewery.com      Oregon
# 2   8135758440                                        None     Florida
# 3   4809460542                      http://www.craft64.com     Arizona
# 4  81675039795  https://craftbeerbase.com/shops/mothertree       Osaka
#
#                      street
# 0              530 Crane St
# 1  62988 Layton Ave Ste 103
# 2    2624 Land O Lakes Blvd
# 3            6922 E Main St
# 4         1-13-13 Oyodonaka

# %% [markdown]
# ---
#
# ## Task 2: Filter by Location
#
# Use the `/breweries` endpoint with **filter parameters**. This endpoint allows you to filter by:
# - `by_city` - Filter by city name (e.g., "San Diego")
# - `by_state` - Filter by state name (e.g., "California")
# - `by_postal` - Filter by postal code (e.g., "92101")
# - `by_type` - Filter by brewery type (micro, nano, regional, brewpub, large, planning, bar, contract, proprietor)
#
# Create **one query** that uses the filter endpoint. Convert to DataFrame and display top 5 rows.
#
# **Example:**

# %%
# Example: Find micro breweries in Champaign, Illinois
url = "https://api.openbrewerydb.org/v1/breweries/search"
filter_url = f"{base_url}/breweries"

params_filter = {
    'by_city': 'Champaign',
    'by_state': 'Illinois',
    'by_type': 'micro',
    'per_page': 10
}
response_filter = requests.get(filter_url, params=params_filter)
df_filter = pd.DataFrame(response_filter.json())
df_filter.head()
print(response_filter.status_code)
print(len(response_filter.json()))
# Out:
# 200
# 0

# %% [markdown]
# ---
#
# ## Task 3: Random Breweries
#
# Use the `/breweries/random` endpoint to get random breweries. This endpoint accepts:
# - `size` - Number of random breweries to return (default: 1, max: 50)
#
# Get **5 random breweries**, convert to DataFrame, and display all rows.
#
# **Hint:** The URL should be `http://178.156.206.171:8000/breweries/random`

# %%
# Your code for Task 3 here

# Hint: The URL should be http://178.156.206.171:8000/breweries/random
random_url = "http://178.156.206.171:8000/breweries/random"

params_random = {
    'size': 5   # 🔹 number of random breweries to return
}
response_random = requests.get(random_url, params=params_random)
df_random = pd.DataFrame(response_random.json())
df_random
# Out:
#                                      id                              name  \
# 0  547f2a09-6f76-4801-a631-ed0b0b9ffb60           New Glory Craft Brewery
# 1  12b869d0-0f6e-4cff-a6c6-04532f770c00       Heavier Than Air Brewing Co
# 2  29c1c73e-3eac-4a09-8fd2-16967e838f9e   Denver Beer Co Olde Town Arvada
# 3  c7296318-3def-485e-9f58-b76d2db04b25            Pigeon Hill Brewing Co
# 4  6e59f361-2d17-4beb-ac3b-92d2a4d437d0  Rowlands Calumet Brewery Co (#2)
#
#   brewery_type                      address_1 address_2 address_3  \
# 0        micro                8251 Alpine Ave      None      None
# 1        micro  497 Miamisburg Centerville Rd      None      None
# 2        micro       5768 Olde Wadsworth Blvd      None      None
# 3        micro      500 W Western Ave Ste 100      None      None
# 4        micro                   57 School St      None      None
#
#           city state_province postal_code        country       phone  \
# 0   Sacramento     California  95826-4708  United States  9164519355
# 1  Centerville           Ohio  45459-4753  United States  9374331500
# 2       Arvada       Colorado  80002-2549  United States  7208925367
# 3     Muskegon       Michigan  49440-1000  United States  2313755184
# 4      Chilton      Wisconsin      53014-  United States  9208492534
#
#                                          website_url   longitude   latitude
# 0                        http://www.newglorybeer.com -121.402102  38.535629
# 1               http://www.heavierthanairbrewing.com  -84.173331  39.627968
# 2  https://denverbeerco.com/taprooms/olde-town-ar... -105.081455  39.801625
# 3                      http://www.pigeonhillbrew.com         NaN        NaN
# 4                                               None  -88.164013  44.029183

# %% [markdown]
# ---
#
# ## Task 4: Autocomplete Search
#
# Use the `/breweries/autocomplete` endpoint to search for brewery names. This is useful for implementing search-as-you-type functionality.
#
# Parameters:
# - `query` - Search term (e.g., "stone")
#
# Search for breweries starting with **"stone"** and display results.
#
# **Note:** This endpoint returns simplified data (just `id` and `name`).

# %%
# Your code for Task 4 here
autocomplete_url = "https://api.openbrewerydb.org/v1/breweries/autocomplete"

params_auto = {
    'query': 'stone'   # 🔹 search term
}
response_auto = requests.get(autocomplete_url, params=params_auto)
df_auto = pd.DataFrame(response_auto.json())
df_auto
# Out:
#                                       id  \
# 0   273491b7-30e3-4ee4-ac6e-f1cfb9194b93
# 1   28e04f1d-11f9-4ea9-b67c-a155e8c88b81
# 2   3ccda21a-5229-4bb1-b442-eb96ed891145
# 3   444ce3b3-4111-485a-9158-e54d61909650
# 4   73832571-cba1-4383-bd2d-d72ef2e0a053
# 5   770c8d54-dcf1-456b-a864-84a4cf0071e1
# 6   780e7ec6-7c19-46d4-90b4-875fc9cfa207
# 7   84999fdf-4d0e-4da9-aaae-dd03bc6ae567
# 8   985764fc-a5cf-4634-8bf3-e89dde5e6531
# 9   9916848b-15ac-44f9-90a5-81ad7b53fde5
# 10  b02a3dcf-6e21-4ae4-9c14-efdd618b42d6
# 11  d2e1b8ab-b0e2-409a-9faa-9ca571815a02
# 12  d955991a-9377-4f2c-baf3-b561a72bf895
# 13  dcca22b1-b172-458b-b71b-7a2866fff776
# 14  e0a66be0-edf0-405e-b6cb-44dcff79fac5
# 15  f2e2ffbe-e126-494d-925a-6d79f87cadfc
# 16  fc3ff19c-3ec3-415c-bb80-b2f6c311f4e7
# 17  0330697d-08ce-4f09-948c-9928532c5755
# 18  06fd21ca-1d18-4d79-a8ab-407d74c55cb7
# 19  259107e5-6645-48b5-a986-80d207d43aa0
# 20  572461d6-ab19-4469-b9c8-937a98b37941
# 21  58092f14-3cd5-47c0-8077-7f11c1ef9e96
# 22  772310d2-06d3-42c6-b494-7622dc87b15d
# 23  84278f35-1caf-4c58-8446-4f6af8a17661
# 24  86b7e9cb-6267-4f6b-a5da-6293aae28ced
# 25  e4a8b737-6725-4ec2-b635-e43f8fcb1de4
# 26  33228a1a-cbb2-4251-8d61-adae85bf78c4
# 27  3fc5efe8-363a-4251-89e3-520d90075666
# 28  6ce0f40e-a10e-4dde-82a6-c51662b2fe09
# 29  87b318f5-5c45-4e21-b577-5389e650453a
# 30  c179ca31-f60a-4726-9ca8-96774c426f00
# 31  ee6d39c6-092f-4623-8099-5b8643f70dbe
# 32  83d47922-0a23-4b85-9c1c-d50b9135d64a
# 33  d60a6feb-13cc-4b3f-b501-a784512982ec
# 34  e13e9d88-359f-4e3d-b981-4753940c5455
# 35  b66534e0-f458-43b0-b9b4-e72487d9414e
# 36  c7e84585-1dd0-4edb-86e9-283a6afd12ff
# 37  8ecb30eb-3537-4b11-8925-b63f09a0b3c9
# 38  016a77de-4e94-4a8a-9bdb-ef03052b4224
# 39  08b8bac1-e93f-48cf-9b2d-8a216d721f46
# 40  16d20128-a551-4eb6-bb79-71b9c2943e35
# 41  2540a41e-870c-4298-b711-e9b1da63bc2d
# 42  388c4362-24d8-493c-95c2-fc86d6ac2a1e
# 43  4f20644c-efbe-4c66-932e-712507f9e99e
# 44  5623e30f-2e4e-44ba-924b-52e4c4551609
# 45  667f8870-c7eb-4b5d-8d80-3fa37f7e1de7
# 46  77a8265c-2d3b-4f30-babe-87a1e0a4c37d
# 47  89f7f1eb-3dbd-40d1-b530-aad3166b8ef0
# 48  a2515bf8-f823-45a8-a3b3-eb94815218ee
# 49  a93eb7a0-8cfe-4d36-9368-115a290c47c9
#
#                                                  name brewery_type  \
# 0                                  Stone Brewing Napa       closed
# 1                                   Stone Cow Brewery        micro
# 2                                       Stone Brewing        micro
# 3                          Stone Brewing Co- Richmond     regional
# 4        Stone Cellar Brewpub / Stone Arch Brew House      brewpub
# 5   Stone Brewing World Bistro & Gardens- Liberty ...      brewpub
# 6                               Stone's Throw Brewing      brewpub
# 7                            Stone & Wood Brewing Co.        large
# 8                        Stone Barrel Brewing Company     regional
# 9                                Stone Church Brewing        micro
# 10                               Stone Corral Brewery        micro
# 11                       Stone Church Pizza & Brewpub      brewpub
# 12                                   Stone Brewing Co     regional
# 13                              Stone Pine Distillery        micro
# 14                       Stone Hollow Brewing Company        micro
# 15                                 The Village Corner      brewpub
# 16                            Stone & Wood Brewing Co        micro
# 17                          Stonehome Brewing Company      brewpub
# 18                               Stoneface Brewing Co        micro
# 19                                  Stoney Acres Farm      brewpub
# 20                             StoneyHead Brewing LLC        micro
# 21                          Stoneyard Brewing Company      brewpub
# 22                                   Stoneman Brewery        micro
# 23                             Stonecloud Brewing Co.        micro
# 24                          Stonehome Brewing Company      brewpub
# 25                               Stones Throw Brewery        micro
# 26                               Lydian Stone Brewery        micro
# 27                          Standing Stone Brewing Co        micro
# 28                           Big Bear Lake Brewing Co      brewpub
# 29                         Foley Brothers Brewing Co.        micro
# 30                       Cape Charles Brewing Company      brewpub
# 31                                   16 Stone Brewpub      brewpub
# 32                           5 Stones Artisan Brewery        micro
# 33                           Southern Tier Brewing Co     regional
# 34                              Ludlam Island Brewery        micro
# 35               Northern Outer Banks Brewing Company        micro
# 36                                   Jones Brewing Co     contract
# 37                            Brew Republic Bierwerks      brewpub
# 38                            Stony Creek Brewing Co.        micro
# 39        Gordon Biersch Brewery Restaurant - Buffalo      brewpub
# 40                           Idletyme Brewing Company      brewpub
# 41                         Stony Lake Brewing Company        micro
# 42                     Hepworth & Company Brewing Ltd        micro
# 43              Welpman Springs Brewing Company, LLC.       closed
# 44                                     Stover Brewing     planning
# 45      Stony Creek Brewery At Foxwoods Resort Casino       closed
# 46                                  Von Trapp Brewing        micro
# 47                          Unleashed Brewing Company       closed
# 48                         The Beer'd Brewing Company        micro
# 49                           Stoker's Brewing Company     planning
#
#                                             address_1  \
# 0                                920-930 Third Street
# 1                             500 West St (Route 122)
# 2                              100 Centennial Circuit
# 3                               4300 Williamsburg Ave
# 4                          1004 S Olde Oneida St Uppr
# 5                    2816 Historic Decatur Rd Ste 116
# 6                                        402 E 9th St
# 7                                    35 Kite Crescent
# 8                                     Bluebell Avenue
# 9                               2785 Cabot Dr Ste 160
# 10                            83 Huntington Rd Unit 1
# 11                                 600 S Hermitage Rd
# 12                              2120 Harmony Grove Rd
# 13                              13594 Princes Highway
# 14                                   301 Court Street
# 15                             6655 James B Rivers Dr
# 16                                   35 Kite Crescent
# 17                                     1601 N 12th St
# 18                             436 Shattuck Way Ste 6
# 19                                  7002 Rangeline Rd
# 20                            5301 Longley Ln Ste 84C
# 21                                     48 Merchant St
# 22                                 20 Stetson Bros Rd
# 23                             1012 NW 1st St Ste 101
# 24                               313 Fox Hills Pkwy N
# 25                                  1009 Larrabee Ave
# 26                                  685 York Haven Rd
# 27                                         101 Oak St
# 28                                     40827 Stone Rd
# 29                               79 Stone Mill Dam Rd
# 30                                      2198 Stone Rd
# 31                                       9542 Main St
# 32                     11335 Farm To Market Road 1863
# 33                                  2072 Stoneman Cir
# 34                                 9 Stoney Ct Unit 3
# 35                                  520 Old Stoney Rd
# 36                                  254 Second Street
# 37  15201 Potomac Town Pl Ste 120 Stonebridge @ Po...
# 38                                88 Limestone Street
# 39                             Store P102 Galleria Dr
# 40                                   1859 Mountain Rd
# 41                                 447 E Michigan Ave
# 42                                       Stane Street
# 43                                    517 Hatchery Rd
# 44                                               None
# 45                                               None
# 46                                  1333 Luce Hill Rd
# 47                                               None
# 48                              22 Bayview Ave Ste 15
# 49                                               None
#
#                      address_2  address_3                city  state_province  \
# 0                         None       None                Napa      California
# 1                         None       None               Barre   Massachusetts
# 2                         None       None           Byron Bay             NSW
# 3                         None       None            Richmond        Virginia
# 4                         None       None            Appleton       Wisconsin
# 5                         None       None           San Diego      California
# 6                         None       None         Little Rock        Arkansas
# 7                         None       None  South Murwillumbah             NSW
# 8   Bluebell Industrial Estate  Dublin 12              Dublin          Dublin
# 9                         None       None              Corona      California
# 10                        None       None            Richmond         Vermont
# 11                        None       None           Hermitage    Pennsylvania
# 12                        None       None           Escondido      California
# 13                        None       None         Stony Creek             NSW
# 14                        None       None            Beatrice        Nebraska
# 15                        None       None      Stone Mountain         Georgia
# 16                        None       None  South Murwillumbah             NSW
# 17                        None       None            Bismarck    North Dakota
# 18                        None       None           Newington   New Hampshire
# 19                        None       None              Athens       Wisconsin
# 20                        None       None                Reno          Nevada
# 21                        None       None           Brockport        New York
# 22                        None       None             Colrain   Massachusetts
# 23                        None       None       Oklahoma City        Oklahoma
# 24                        None       None        Watford City    North Dakota
# 25                        None       None          Bellingham      Washington
# 26                        None       None          York Haven    Pennsylvania
# 27                        None       None             Ashland          Oregon
# 28                        None       None       Big Bear Lake      California
# 29                        None       None             Brandon         Vermont
# 30                        None       None        Cape Charles        Virginia
# 31                        None       None      Holland Patent        New York
# 32                        None       None       New Braunfels           Texas
# 33                        None       None            Lakewood        New York
# 34                        None       None          Ocean View      New Jersey
# 35                        None       None             Corolla  North Carolina
# 36                        None       None            Smithton    Pennsylvania
# 37                        None       None          Woodbridge        Virginia
# 38                     Block C       None             Ipswich             QLD
# 39                        None       None         Cheektowaga        New York
# 40                        None       None               Stowe         Vermont
# 41                        None       None              Saline        Michigan
# 42                        None       None          Pulborough     West Sussex
# 43                        None       None              Stover        Missouri
# 44                        None       None           San Diego      California
# 45                        None       None        Mashantucket     Connecticut
# 46                        None       None               Stowe         Vermont
# 47                        None       None          Stonington     Connecticut
# 48                        None       None          Stonington     Connecticut
# 49                        None       None             Tamaqua    Pennsylvania
#
#    postal_code        country   longitude   latitude            phone  \
# 0        94559  United States -122.282968  38.298967       7602947899
# 1        01005  United States         NaN        NaN       4135526048
# 2         2481      Australia  153.580758 -28.637169  +61 429 060 262
# 3   23231-1225  United States  -77.414763  37.524110       8044895902
# 4   54915-1753  United States         NaN        NaN       9207313322
# 5   92106-6164  United States -117.211570  32.740524       6192692200
# 6   72202-3914  United States  -92.268066  34.739789       5012449154
# 7         2484      Australia  153.422350 -28.342698  +61 2 6685 5173
# 8     D12 NPF9        Ireland   -6.350665  53.330880     353862381267
# 9   92883-7388  United States -117.504624  33.813181       3105676582
# 10  05477-9839  United States         NaN        NaN       8024345787
# 11  16148-3629  United States  -80.451969  41.225649       7243087770
# 12  92029-2053  United States -117.115650  33.109969       7602947866
# 13        2550      Australia  149.839896 -36.604198  +61 448 294 210
# 14       68310  United States  -96.750636  40.265751       4028064664
# 15  30083-2232  United States         NaN        NaN       7704980329
# 16        2484      Australia  153.422350 -28.342698  +61 2 6685 5173
# 17  58501-2713  United States -100.773737  46.823656       7017511445
# 18  03801-7838  United States         NaN        NaN             None
# 19       54411  United States         NaN        NaN       7154326285
# 20  89511-1873  United States         NaN        NaN       7758292337
# 21       14420  United States         NaN        NaN       5856373390
# 22  01340-9733  United States         NaN        NaN       4136245195
# 23  73106-7642  United States  -97.529142  35.468613       4056023966
# 24       58854  United States -103.258057  47.882101       7014442337
# 25  98225-7338  United States -122.497165  48.718516       3603625058
# 26  17370-9006  United States  -76.715729  40.094426       7173846055
# 27  97520-1802  United States -122.714579  42.197645       5414822448
# 28       92315  United States -116.911029  34.242558       9098780283
# 29  05733-8945  United States         NaN        NaN       8024658413
# 30  23310-2706  United States  -75.992111  37.269795       7574494839
# 31       13354  United States  -75.256519  43.242112       3158658500
# 32       78132  United States  -98.232345  29.711365       2103808215
# 33  14750-9779  United States         NaN        NaN       7167635479
# 34  08230-1041  United States         NaN        NaN       6092636969
# 35       27927  United States         NaN        NaN       2522071890
# 36  15479-0746  United States         NaN        NaN             None
# 37  22191-6592  United States         NaN        NaN       7035947950
# 38        4305      Australia  152.757692 -27.615379  +61 435 380 290
# 39  14225-5408  United States         NaN        NaN       7166830050
# 40  05672-4890  United States  -72.698401  44.473833       8022534765
# 41  48176-1547  United States  -83.773535  42.170417       7343167919
# 42    RH20 1DJ        England   -0.478064  50.989042       1403269696
# 43  65078-1132  United States         NaN        NaN       5733772343
# 44  92124-1426  United States -117.162771  32.717421       6193634677
# 45  06338-3830  United States         NaN        NaN       8603123000
# 46       05672  United States  -72.791432  44.470714       8022535750
# 47  06378-1628  United States         NaN        NaN             None
# 48  06378-1143  United States         NaN        NaN       8602139307
# 49  18252-1405  United States         NaN        NaN             None
#
#                                           website_url           state  \
# 0                                                None      California
# 1                                                None   Massachusetts
# 2   https://stoneandwood.com.au/pages/byron-bay?ut...             NSW
# 3   http://www.stonebrewing.com/visit/outposts/ric...        Virginia
# 4                   http://www.stonecellarbrewpub.com       Wisconsin
# 5                  http://www.stonelibertystation.com      California
# 6                      http://www.stonesthrowbeer.com        Arkansas
# 7                        https://stoneandwood.com.au/             NSW
# 8                   http://www.stonebarrelbrewing.ie/          Dublin
# 9                   http://www.stonechurchbrewing.com      California
# 10                             http://stonecorral.com         Vermont
# 11                  http://www.stonechurchbrewpub.com    Pennsylvania
# 12                        http://www.stonebrewing.com      California
# 13                     http://www.northofeden.com.au/             NSW
# 14                 https://www.stonehollowbrewing.com        Nebraska
# 15                     http://www.germanresturant.com         Georgia
# 16                       https://stoneandwood.com.au/             NSW
# 17                    http://www.stonehomebrewing.com    North Dakota
# 18                    http://www.stonefacebrewing.com   New Hampshire
# 19                     http://www.stoneyacresfarm.net       Wisconsin
# 20                   http://www.stoneyheadbrewing.com          Nevada
# 21             http://www.stoneyardbrewingcompany.com        New York
# 22                                               None   Massachusetts
# 23                       http://stonecloudbrewing.com        Oklahoma
# 24                    http://www.stonehomebrewing.com    North Dakota
# 25                   http://www.stonesthrowbrewco.com      Washington
# 26                  http://www.lydianstonebrewing.com    Pennsylvania
# 27                http://www.standingstonebrewing.com          Oregon
# 28                               http://www.bblbc.com      California
# 29                                               None         Vermont
# 30                  http://www.capecharlesbrewing.com        Virginia
# 31                      http://www.16stonebrewpub.com        New York
# 32                                               None           Texas
# 33                 http://www.southerntierbrewing.com        New York
# 34                            http://ludlamisland.com      New Jersey
# 35                  http://www.northernobxbrewing.com  North Carolina
# 36                         http://www.stoneysbeer.com    Pennsylvania
# 37                           http://brewrepublic.beer        Virginia
# 38                  https://stonycreekbrewing.com.au/             QLD
# 39               http://www.craftworksrestaurants.com        New York
# 40                     http://www.idletymebrewing.com         Vermont
# 41                    http://www.stonylakebrewing.com        Michigan
# 42                     https://hepworthbrewery.co.uk/     West Sussex
# 43        http://www.welpmanspringsbrewing.weebly.com        Missouri
# 44                       http://www.stoverbrewing.com      California
# 45                                               None     Connecticut
# 46                         http://www.trappfamily.com         Vermont
# 47                    http://www.unleashedbrewing.com     Connecticut
# 48                        http://www.beerdbrewing.com     Connecticut
# 49                                               None    Pennsylvania
#
#                                                street
# 0                                920-930 Third Street
# 1                             500 West St (Route 122)
# 2                              100 Centennial Circuit
# 3                               4300 Williamsburg Ave
# 4                          1004 S Olde Oneida St Uppr
# 5                    2816 Historic Decatur Rd Ste 116
# 6                                        402 E 9th St
# 7                                    35 Kite Crescent
# 8                                     Bluebell Avenue
# 9                               2785 Cabot Dr Ste 160
# 10                            83 Huntington Rd Unit 1
# 11                                 600 S Hermitage Rd
# 12                              2120 Harmony Grove Rd
# 13                              13594 Princes Highway
# 14                                   301 Court Street
# 15                             6655 James B Rivers Dr
# 16                                   35 Kite Crescent
# 17                                     1601 N 12th St
# 18                             436 Shattuck Way Ste 6
# 19                                  7002 Rangeline Rd
# 20                            5301 Longley Ln Ste 84C
# 21                                     48 Merchant St
# 22                                 20 Stetson Bros Rd
# 23                             1012 NW 1st St Ste 101
# 24                               313 Fox Hills Pkwy N
# 25                                  1009 Larrabee Ave
# 26                                  685 York Haven Rd
# 27                                         101 Oak St
# 28                                     40827 Stone Rd
# 29                               79 Stone Mill Dam Rd
# 30                                      2198 Stone Rd
# 31                                       9542 Main St
# 32                     11335 Farm To Market Road 1863
# 33                                  2072 Stoneman Cir
# 34                                 9 Stoney Ct Unit 3
# 35                                  520 Old Stoney Rd
# 36                                  254 Second Street
# 37  15201 Potomac Town Pl Ste 120 Stonebridge @ Po...
# 38                                88 Limestone Street
# 39                             Store P102 Galleria Dr
# 40                                   1859 Mountain Rd
# 41                                 447 E Michigan Ave
# 42                                       Stane Street
# 43                                    517 Hatchery Rd
# 44                                               None
# 45                                               None
# 46                                  1333 Luce Hill Rd
# 47                                               None
# 48                              22 Bayview Ave Ste 15
# 49                                               None

# %% [markdown]
# ---
#
# ## Task 5: Get Brewery by ID
#
# Use the `/breweries/{id}` endpoint to get a specific brewery by its UUID.
#
# **Instructions:**
# 1. First, use any search/filter query to get a list of breweries
# 2. Extract the `id` of the first brewery in your results
# 3. Use that ID to fetch the full brewery details
# 4. Print the JSON response (formatted)
#
# **Example ID:** You'll get this from your search results

# %%
# Step 1: Get a list of breweries to find an ID
# (Use any search/filter from previous tasks)
base_url = "https://api.openbrewerydb.org/v1"
search_url = f"{base_url}/breweries/search"

params_search = {
    'query': 'mountain',
    'per_page': 5
}

response_search = requests.get(search_url, params=params_search)
df_search = pd.DataFrame(response_search.json())

# %%
# Step 2: Extract the ID from the first result
# brewery_id = df['id'].iloc[0]  # Example
brewery_id = df_search['id'].iloc[0]
print("Brewery ID:", brewery_id)

# Step 3: Fetch brewery by ID
# brewery_url = f'{base_url}/breweries/{brewery_id}'
# Your code here
brewery_url = f"{base_url}/breweries/{brewery_id}"
response_brewery = requests.get(brewery_url)
print(json.dumps(response_brewery.json(), indent=4))
# Out:
# Brewery ID: 251596fe-58b7-4690-a823-f8c65be73228
# {
#     "id": "251596fe-58b7-4690-a823-f8c65be73228",
#     "name": "Mountain View Brewing",
#     "brewery_type": "micro",
#     "address_1": "6670 Trout Creek Ridge Rd",
#     "address_2": null,
#     "address_3": null,
#     "city": "Mt Hood",
#     "state_province": "Oregon",
#     "postal_code": "97041",
#     "country": "United States",
#     "longitude": -121.6229737,
#     "latitude": 45.53707415,
#     "phone": "5414410314",
#     "website_url": "https://www.mtviewbrewing.com/",
#     "state": "Oregon",
#     "street": "6670 Trout Creek Ridge Rd"
# }

# %% [markdown]
# ---
#
# ## Task 6: Combining Multiple Queries
#
# Create a query that combines data from **two different API calls**.
#
# **Example:**
# - Get all breweries in California (`by_state=California`)
# - Get all breweries in Texas (`by_state=Texas`)
# - Combine both DataFrames using `pd.concat()`
# - Show summary statistics (count by state, count by type, etc.)
#
# **Your task:** Choose your own combination and analyze the results.

# %%
# Your code for Task 6 here
# Make two API calls
# Combine the results
# Perform analysis

# %% [markdown]
# ---
#
# ## Submission Instructions
#
# 1. Complete all 6 tasks above
# 2. Ensure all code cells run without errors
# 3. Make sure DataFrames display properly
# 4. Download your completed notebook: File → Download → Download .ipynb
# 5. Submit to the **Class Participation Assignment** on Canvas
#
# ---
#
# ## Advanced Challenge (Optional - Extra Credit)
#
# For students who want an extra challenge:
#
# **Create a comprehensive brewery analysis:**
# 1. Find the **top 5 states** with the most breweries
# 2. For each of those states, get the **distribution of brewery types**
# 3. Create a summary table showing:
#    - State name
#    - Total brewery count
#    - Count by type (micro, nano, brewpub, etc.)
# 4. Visualize the results using a bar chart (use `matplotlib` or `seaborn`)
#
# **Hint:** You'll need to:
# - Use the `/breweries/meta` endpoint to get counts
# - Make multiple filtered API calls
# - Use pandas groupby and aggregation functions
# - Create visualizations

# %%
# Your advanced challenge code here (optional)

# %% [markdown]
# ---
#
# ## Additional Resources
#
# - **API Interactive Docs:** http://178.156.206.171:8000/docs
# - **API Health Check:** http://178.156.206.171:8000/health
# - **Pandas Documentation:** https://pandas.pydata.org/docs/
# - **Requests Library:** https://requests.readthedocs.io/
#
# ## Tips for Success
#
# 1. **Always check the status code** - 200 means success
# 2. **Print the response URL** - Helps debug parameter issues
# 3. **Use `.json()` method** - Converts response to Python dict
# 4. **Use `json.dumps()`** - Pretty print JSON for readability
# 5. **Check DataFrame shape** - Ensure you got the expected data
# 6. **Use descriptive variable names** - Makes code easier to follow
#
# ## Common Errors and Solutions
#
# | Error | Cause | Solution |
# |-------|-------|----------|
# | `ConnectionError` | API server unreachable | Check internet connection, verify URL |
# | `Timeout` | Request took too long | Increase timeout value |
# | `JSONDecodeError` | Response is not valid JSON | Check status code, print response.text |
# | `KeyError` | Trying to access missing key | Check available keys with `.keys()` |
# | Empty DataFrame | No results found | Verify your query parameters |
#
# Good luck! 🍺
